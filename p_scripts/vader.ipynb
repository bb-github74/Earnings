# %% [markdown]
# # Valence Aware Dictionary and sEntiment Reasoner

# %%
# Author: bbaasan
# File: vader.ipynb
# Created: 2023-09-13
# Email: bbaasan@gmu.edu
# Purpose: adding sentiment score to the data

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
aggregated = pd.read_pickle('../data/Aggregated.pkl')

# %%
vader_analyzer = SentimentIntensityAnalyzer()

def apply_vader_sentiment(dataframe: pd.DataFrame=None):
    output_dict = {'neg':[],'neu':[],'pos':[]}
    for idx, row in enumerate(dataframe.to_dict('records')):
        if idx%5==0:
            print(f'working on the: {idx}')
        text = [ line.strip() for line in row['transcript']]  # stript escape line character s
        single_sentence = ' '.join(text)
        sentiment_scores = vader_analyzer.polarity_scores(single_sentence)
        output_dict['neg'].append(sentiment_scores['neg'])
        output_dict['neu'].append(sentiment_scores['neu'])
        output_dict['pos'].append(sentiment_scores['pos'])
     
    return pd.DataFrame(output_dict)

# %%
import pandas as pd
import threading

# Assume you have vader_analyzer initialized already
# You can also import vader_analyzer from a module

# Define your apply_vader_sentiment function
def apply_vader_sentiment(dataframe: pd.DataFrame, thread_id, num_threads):
    output_dict = {'neg': [], 'neu': [], 'pos': []}
    for idx, row in enumerate(dataframe.to_dict('records')):
        if idx % 5 == 0:
            print(f'Thread {thread_id}: working on row {idx}')
        if idx % num_threads != thread_id:
            continue  # Skip rows not assigned to this thread
        text = [line.strip() for line in row['transcript']]
        single_sentence = ' '.join(text)
        sentiment_scores = vader_analyzer.polarity_scores(single_sentence)
        output_dict['neg'].append(sentiment_scores['neg'])
        output_dict['neu'].append(sentiment_scores['neu'])
        output_dict['pos'].append(sentiment_scores['pos'])
    return pd.DataFrame(output_dict)

# Define the number of threads to use
num_threads = 4

# Calculate the chunk size for each thread
chunk_size = len(aggregated) // num_threads

# Create a list to store the results from each thread
results = [None] * num_threads

# Create and start the threads
threads = []
for i in range(num_threads):
    start_idx = i * chunk_size
    end_idx = (i + 1) * chunk_size if i < num_threads - 1 else None
    sub_df = aggregated.iloc[start_idx:end_idx]
    thread = threading.Thread(target=lambda i=i: results.__setitem__(i, apply_vader_sentiment(sub_df, i, num_threads)))
    threads.append(thread)
    thread.start()

# Wait for all threads to finish
for thread in threads:
    thread.join()

# Combine the results from all threads if needed
combined_result = pd.concat(results, ignore_index=True)

# Now, combined_result contains the sentiment analysis results for the entire DataFrame
# Out:
# Thread 3: working on row 0
# Thread 2: working on row 0
# Thread 1: working on row 0
# Thread 0: working on row 0
# Thread 1: working on row 5
# Thread 3: working on row 5
# Thread 1: working on row 10
# Thread 2: working on row 5
# Thread 0: working on row 5
# Thread 3: working on row 10
# Thread 2: working on row 10
# Thread 3: working on row 15
# Thread 1: working on row 15
# Thread 0: working on row 10
# Thread 0: working on row 15
# Thread 2: working on row 15
# Thread 2: working on row 20
# Thread 1: working on row 20
# Thread 3: working on row 20
# Thread 0: working on row 20
# Thread 2: working on row 25
# Thread 1: working on row 25
# Thread 3: working on row 25
# Thread 0: working on row 25
# Thread 0: working on row 30
# Thread 2: working on row 30
# Thread 1: working on row 30
# Thread 3: working on row 30
# Thread 3: working on row 35
# Thread 0: working on row 35
# Thread 1: working on row 35
# Thread 2: working on row 35
# Thread 0: working on row 40
# Thread 2: working on row 40
# Thread 2: working on row 45
# Thread 3: working on row 40
# Thread 2: working on row 50
# Thread 1: working on row 40
# Thread 3: working on row 45
# Thread 1: working on row 45
# Thread 3: working on row 50
# Thread 0: working on row 45
# Thread 1: working on row 50Thread 3: working on row 55
#
# Thread 3: working on row 60
# Thread 0: working on row 50
# Thread 1: working on row 55
# Thread 2: working on row 55
# Thread 1: working on row 60
# Thread 2: working on row 60
# Thread 3: working on row 65
# Thread 1: working on row 65
# Thread 0: working on row 55
# Thread 2: working on row 65
# Thread 2: working on row 70
# Thread 3: working on row 70
# Thread 0: working on row 60
# Thread 1: working on row 70
# Thread 3: working on row 75
# Thread 1: working on row 75
# Thread 2: working on row 75
# Thread 1: working on row 80
# Thread 0: working on row 65
# Thread 1: working on row 85
# Thread 2: working on row 80
# Thread 0: working on row 70
# Thread 2: working on row 85
# Thread 2: working on row 90
# Thread 0: working on row 75
# Thread 2: working on row 95
# Thread 3: working on row 80
# Thread 3: working on row 85
# Thread 1: working on row 90
# Thread 2: working on row 100
# Thread 0: working on row 80
# Thread 1: working on row 95
# Thread 0: working on row 85
# Thread 2: working on row 105
# Thread 3: working on row 90
# Thread 2: working on row 110
# Thread 3: working on row 95
# Thread 1: working on row 100
# Thread 3: working on row 100
# Thread 0: working on row 90
# Thread 3: working on row 105
# Thread 1: working on row 105
# Thread 0: working on row 95
# Thread 2: working on row 115
# Thread 3: working on row 110
# Thread 3: working on row 115
# Thread 2: working on row 120
# Thread 0: working on row 100
# Thread 2: working on row 125
# Thread 2: working on row 130
# Thread 1: working on row 110
# Thread 0: working on row 105
# Thread 3: working on row 120
# Thread 1: working on row 115
# Thread 3: working on row 125
# Thread 1: working on row 120
# Thread 2: working on row 135
# Thread 3: working on row 130
# Thread 0: working on row 110
# Thread 3: working on row 135
# Thread 1: working on row 125
# Thread 2: working on row 140
# Thread 2: working on row 145
# Thread 2: working on row 150
# Thread 3: working on row 140
# Thread 3: working on row 145
# Thread 3: working on row 150
# Thread 0: working on row 115
# Thread 1: working on row 130
# Thread 1: working on row 135
# Thread 0: working on row 120
# Thread 2: working on row 155
# Thread 2: working on row 160
# Thread 3: working on row 155
# Thread 1: working on row 140
# Thread 0: working on row 125
# Thread 0: working on row 130Thread 1: working on row 145
#
# Thread 2: working on row 165
# Thread 2: working on row 170
# Thread 3: working on row 160
# Thread 3: working on row 165
# Thread 1: working on row 150
# Thread 1: working on row 155
# Thread 0: working on row 135
# Thread 1: working on row 160
# Thread 2: working on row 175
# Thread 2: working on row 180
# Thread 0: working on row 140
# Thread 1: working on row 165
# Thread 3: working on row 170
# Thread 2: working on row 185
# Thread 2: working on row 190
# Thread 3: working on row 175
# Thread 1: working on row 170
# Thread 1: working on row 175
# Thread 0: working on row 145
# Thread 3: working on row 180
# Thread 1: working on row 180
# Thread 2: working on row 195
# Thread 2: working on row 200
# Thread 1: working on row 185
# Thread 2: working on row 205
# Thread 2: working on row 210
# Thread 2: working on row 215
# Thread 3: working on row 185
# Thread 0: working on row 150
# Thread 2: working on row 220
# Thread 2: working on row 225
# Thread 0: working on row 155
# Thread 2: working on row 230
# Thread 3: working on row 190
# Thread 1: working on row 190
# Thread 0: working on row 160
# Thread 0: working on row 165
# Thread 1: working on row 195
# Thread 2: working on row 235
# Thread 0: working on row 170
# Thread 3: working on row 195
# Thread 0: working on row 175
# Thread 2: working on row 240
# Thread 0: working on row 180
# Thread 2: working on row 245
# Thread 1: working on row 200
# Thread 3: working on row 200
# Thread 2: working on row 250
# Thread 3: working on row 205
# Thread 1: working on row 205
# Thread 3: working on row 210
# Thread 0: working on row 185
# Thread 3: working on row 215
# Thread 0: working on row 190
# Thread 0: working on row 195
# Thread 1: working on row 210
# Thread 3: working on row 220
# Thread 2: working on row 255
# Thread 2: working on row 260
# Thread 0: working on row 200
# Thread 1: working on row 215
# Thread 1: working on row 220
# Thread 1: working on row 225
# Thread 3: working on row 225
# Thread 2: working on row 265
# Thread 3: working on row 230
# Thread 0: working on row 205
# Thread 2: working on row 270
# Thread 0: working on row 210
# Thread 3: working on row 235
# Thread 2: working on row 275
# Thread 2: working on row 280
# Thread 0: working on row 215
# Thread 2: working on row 285
# Thread 1: working on row 230
# Thread 1: working on row 235
# Thread 0: working on row 220
# Thread 1: working on row 240
# Thread 3: working on row 240
# Thread 2: working on row 290
# Thread 1: working on row 245
# Thread 3: working on row 245
# Thread 0: working on row 225
# Thread 2: working on row 295
# Thread 0: working on row 230
# Thread 1: working on row 250Thread 3: working on row 250
#
# Thread 1: working on row 255
# Thread 1: working on row 260
# Thread 3: working on row 255
# Thread 2: working on row 300
# Thread 0: working on row 235
# Thread 1: working on row 265
# Thread 0: working on row 240
# Thread 2: working on row 305
# Thread 3: working on row 260
# Thread 1: working on row 270
# Thread 1: working on row 275
# Thread 3: working on row 265
# Thread 2: working on row 310
# Thread 3: working on row 270
# Thread 3: working on row 275
# Thread 1: working on row 280
# Thread 3: working on row 280
# Thread 0: working on row 245
# Thread 2: working on row 315
# Thread 1: working on row 285
# Thread 0: working on row 250
# Thread 2: working on row 320
# Thread 3: working on row 285
# Thread 0: working on row 255
# Thread 2: working on row 325
# Thread 1: working on row 290
# Thread 2: working on row 330
# Thread 2: working on row 335
# Thread 0: working on row 260
# Thread 1: working on row 295
# Thread 3: working on row 290
# Thread 3: working on row 295
# Thread 2: working on row 340
# Thread 0: working on row 265
# Thread 1: working on row 300
# Thread 1: working on row 305
# Thread 3: working on row 300
# Thread 2: working on row 345
# Thread 2: working on row 350
# Thread 3: working on row 305
# Thread 0: working on row 270
# Thread 2: working on row 355
# Thread 2: working on row 360
# Thread 2: working on row 365
# Thread 1: working on row 310
# Thread 3: working on row 310
# Thread 1: working on row 315
# Thread 1: working on row 320Thread 2: working on row 370
#
# Thread 0: working on row 275
# Thread 3: working on row 315
# Thread 2: working on row 375
# Thread 0: working on row 280
# Thread 2: working on row 380
# Thread 1: working on row 325
# Thread 3: working on row 320
# Thread 3: working on row 325
# Thread 2: working on row 385
# Thread 3: working on row 330
# Thread 1: working on row 330
# Thread 3: working on row 335
# Thread 0: working on row 285
# Thread 2: working on row 390
# Thread 0: working on row 290
# Thread 1: working on row 335
# Thread 2: working on row 395
# Thread 3: working on row 340
# Thread 0: working on row 295
# Thread 0: working on row 300
# Thread 3: working on row 345
# Thread 1: working on row 340
# Thread 2: working on row 400
# Thread 1: working on row 345
# Thread 3: working on row 350
# Thread 2: working on row 405
# Thread 3: working on row 355
# Thread 0: working on row 305
# Thread 2: working on row 410
# Thread 2: working on row 415
# Thread 1: working on row 350
# Thread 0: working on row 310
# Thread 2: working on row 420
# Thread 0: working on row 315
# Thread 2: working on row 425
# Thread 1: working on row 355
# Thread 3: working on row 360
# Thread 0: working on row 320
# Thread 2: working on row 430
# Thread 1: working on row 360
# Thread 3: working on row 365
# Thread 2: working on row 435
# Thread 0: working on row 325
# Thread 2: working on row 440
# Thread 3: working on row 370
# Thread 0: working on row 330
# Thread 3: working on row 375
# Thread 2: working on row 445
# Thread 3: working on row 380
# Thread 0: working on row 335
# Thread 1: working on row 365
# Thread 2: working on row 450
# Thread 3: working on row 385
# Thread 0: working on row 340
# Thread 3: working on row 390
# Thread 3: working on row 395Thread 1: working on row 370
#
# Thread 3: working on row 400
# Thread 0: working on row 345
# Thread 3: working on row 405
# Thread 1: working on row 375
# Thread 2: working on row 455
# Thread 0: working on row 350
# Thread 3: working on row 410
# Thread 2: working on row 460
# Thread 3: working on row 415
# Thread 1: working on row 380
# Thread 2: working on row 465
# Thread 0: working on row 355
# Thread 1: working on row 385
# Thread 2: working on row 470
# Thread 3: working on row 420
# Thread 0: working on row 360
# Thread 3: working on row 425
# Thread 3: working on row 430
# Thread 3: working on row 435
# Thread 0: working on row 365
# Thread 2: working on row 475
# Thread 0: working on row 370
# Thread 3: working on row 440
# Thread 2: working on row 480
# Thread 3: working on row 445
# Thread 1: working on row 390
# Thread 2: working on row 485
# Thread 2: working on row 490
# Thread 3: working on row 450
# Thread 2: working on row 495
# Thread 0: working on row 375
# Thread 3: working on row 455
# Thread 1: working on row 395
# Thread 0: working on row 380
# Thread 0: working on row 385
# Thread 1: working on row 400
# Thread 1: working on row 405
# Thread 1: working on row 410
# Thread 0: working on row 390
# Thread 0: working on row 395
# Thread 1: working on row 415
# Thread 1: working on row 420
# Thread 3: working on row 460
# Thread 0: working on row 400
# Thread 3: working on row 465
# Thread 2: working on row 500
# Thread 1: working on row 425
# Thread 3: working on row 470
# Thread 2: working on row 505
# Thread 3: working on row 475
# Thread 0: working on row 405
# Thread 1: working on row 430
# Thread 1: working on row 435
# Thread 0: working on row 410
# Thread 3: working on row 480
# Thread 2: working on row 510
# Thread 0: working on row 415
# Thread 1: working on row 440
# Thread 0: working on row 420
# Thread 3: working on row 485
# Thread 2: working on row 515
# Thread 1: working on row 445
# Thread 2: working on row 520
# Thread 2: working on row 525
# Thread 2: working on row 530
# Thread 3: working on row 490
# Thread 2: working on row 535
# Thread 2: working on row 540
# Thread 3: working on row 495
# Thread 1: working on row 450
# Thread 0: working on row 425
# Thread 1: working on row 455
# Thread 2: working on row 545
# Thread 1: working on row 460
# Thread 0: working on row 430
# Thread 2: working on row 550
# Thread 3: working on row 500
# Thread 1: working on row 465
# Thread 3: working on row 505
# Thread 0: working on row 435
# Thread 2: working on row 555
# Thread 3: working on row 510
# Thread 3: working on row 515
# Thread 2: working on row 560
# Thread 0: working on row 440
# Thread 1: working on row 470
# Thread 2: working on row 565
# Thread 1: working on row 475
# Thread 2: working on row 570
# Thread 0: working on row 445
# Thread 0: working on row 450
# Thread 0: working on row 455
# Thread 3: working on row 520Thread 1: working on row 480
#
# Thread 2: working on row 575
# Thread 2: working on row 580
# Thread 3: working on row 525
# Thread 2: working on row 585
# Thread 3: working on row 530Thread 2: working on row 590
#
# Thread 0: working on row 460
# Thread 1: working on row 485
# Thread 3: working on row 535
# Thread 2: working on row 595
# Thread 0: working on row 465
# Thread 1: working on row 490
# Thread 0: working on row 470
# Thread 0: working on row 475
# Thread 0: working on row 480
# Thread 3: working on row 540
# Thread 1: working on row 495
# Thread 1: working on row 500Thread 2: working on row 600
#
# Thread 3: working on row 545
# Thread 0: working on row 485
# Thread 2: working on row 605
# Thread 0: working on row 490
# Thread 3: working on row 550
# Thread 3: working on row 555
# Thread 2: working on row 610
# Thread 1: working on row 505Thread 0: working on row 495
#
# Thread 3: working on row 560
# Thread 1: working on row 510
# Thread 3: working on row 565
# Thread 1: working on row 515
# Thread 3: working on row 570
# Thread 3: working on row 575
# Thread 1: working on row 520
# Thread 3: working on row 580
# Thread 2: working on row 615
# Thread 1: working on row 525
# Thread 3: working on row 585
# Thread 2: working on row 620
# Thread 3: working on row 590
# Thread 1: working on row 530
# Thread 1: working on row 535
# Thread 3: working on row 595
# Thread 0: working on row 500
# Thread 2: working on row 625
# Thread 2: working on row 630
# Thread 1: working on row 540
# Thread 3: working on row 600
# Thread 3: working on row 605
# Thread 1: working on row 545
# Thread 2: working on row 635
# Thread 0: working on row 505
# Thread 2: working on row 640
# Thread 1: working on row 550
# Thread 3: working on row 610
# Thread 1: working on row 555
# Thread 2: working on row 645
# Thread 3: working on row 615
# Thread 1: working on row 560
# Thread 2: working on row 650
# Thread 3: working on row 620
# Thread 0: working on row 510
# Thread 1: working on row 565
# Thread 1: working on row 570
# Thread 2: working on row 655
# Thread 0: working on row 515
# Thread 1: working on row 575
# Thread 2: working on row 660
# Thread 3: working on row 625
# Thread 2: working on row 665
# Thread 0: working on row 520
# Thread 3: working on row 630
# Thread 1: working on row 580
# Thread 2: working on row 670
# Thread 2: working on row 675Thread 3: working on row 635
#
# Thread 2: working on row 680
# Thread 1: working on row 585
# Thread 0: working on row 525
# Thread 2: working on row 685
# Thread 0: working on row 530
# Thread 2: working on row 690
# Thread 1: working on row 590
# Thread 3: working on row 640
# Thread 1: working on row 595
# Thread 3: working on row 645
# Thread 1: working on row 600
# Thread 0: working on row 535
# Thread 1: working on row 605
# Thread 3: working on row 650
# Thread 3: working on row 655
# Thread 0: working on row 540
# Thread 2: working on row 695
# Thread 2: working on row 700
# Thread 1: working on row 610
# Thread 1: working on row 615
# Thread 3: working on row 660
# Thread 1: working on row 620
# Thread 0: working on row 545
# Thread 2: working on row 705
# Thread 2: working on row 710
# Thread 1: working on row 625
# Thread 0: working on row 550
# Thread 3: working on row 665
# Thread 1: working on row 630
# Thread 2: working on row 715
# Thread 0: working on row 555
# Thread 3: working on row 670
# Thread 1: working on row 635Thread 0: working on row 560
#
# Thread 3: working on row 675
# Thread 1: working on row 640
# Thread 2: working on row 720
# Thread 0: working on row 565
# Thread 1: working on row 645
# Thread 2: working on row 725
# Thread 3: working on row 680
# Thread 0: working on row 570Thread 2: working on row 730
#
# Thread 1: working on row 650Thread 0: working on row 575
#
# Thread 3: working on row 685
# Thread 3: working on row 690
# Thread 1: working on row 655
# Thread 3: working on row 695
# Thread 2: working on row 735
# Thread 0: working on row 580
# Thread 1: working on row 660
# Thread 1: working on row 665
# Thread 3: working on row 700
# Thread 0: working on row 585
# Thread 2: working on row 740
# Thread 3: working on row 705
# Thread 0: working on row 590
# Thread 1: working on row 670Thread 2: working on row 745
#
# Thread 3: working on row 710
# Thread 0: working on row 595
# Thread 0: working on row 600
# Thread 3: working on row 715
# Thread 1: working on row 675
# Thread 2: working on row 750
# Thread 3: working on row 720
# Thread 1: working on row 680
# Thread 3: working on row 725
# Thread 1: working on row 685
# Thread 0: working on row 605
# Thread 3: working on row 730
# Thread 3: working on row 735
# Thread 2: working on row 755
# Thread 2: working on row 760
# Thread 2: working on row 765
# Thread 1: working on row 690
# Thread 0: working on row 610
# Thread 3: working on row 740
# Thread 0: working on row 615
# Thread 1: working on row 695
# Thread 1: working on row 700
# Thread 2: working on row 770
# Thread 0: working on row 620
# Thread 3: working on row 745
# Thread 1: working on row 705
# Thread 2: working on row 775
# Thread 2: working on row 780
# Thread 0: working on row 625
# Thread 3: working on row 750
# Thread 2: working on row 785
# Thread 0: working on row 630
# Thread 3: working on row 755
# Thread 1: working on row 710
# Thread 2: working on row 790
# Thread 1: working on row 715
# Thread 3: working on row 760
# Thread 1: working on row 720
# Thread 3: working on row 765
# Thread 2: working on row 795Thread 0: working on row 635
#
# Thread 1: working on row 725
# Thread 2: working on row 800
# Thread 3: working on row 770
# Thread 0: working on row 640
# Thread 2: working on row 805
# Thread 2: working on row 810
# Thread 1: working on row 730
# Thread 3: working on row 775
# Thread 1: working on row 735
# Thread 2: working on row 815
# Thread 2: working on row 820
# Thread 1: working on row 740
# Thread 3: working on row 780
# Thread 0: working on row 645
# Thread 3: working on row 785
# Thread 1: working on row 745
# Thread 2: working on row 825
# Thread 2: working on row 830
# Thread 3: working on row 790
# Thread 3: working on row 795
# Thread 0: working on row 650
# Thread 0: working on row 655
# Thread 1: working on row 750
# Thread 0: working on row 660
# Thread 2: working on row 835
# Thread 2: working on row 840
# Thread 3: working on row 800
# Thread 1: working on row 755
# Thread 3: working on row 805
# Thread 1: working on row 760
# Thread 1: working on row 765
# Thread 2: working on row 845
# Thread 0: working on row 665
# Thread 2: working on row 850
# Thread 3: working on row 810
# Thread 3: working on row 815
# Thread 0: working on row 670
# Thread 2: working on row 855
# Thread 1: working on row 770
# Thread 2: working on row 860
# Thread 3: working on row 820
# Thread 1: working on row 775
# Thread 3: working on row 825
# Thread 0: working on row 675
# Thread 2: working on row 865
# Thread 1: working on row 780
# Thread 3: working on row 830
# Thread 0: working on row 680
# Thread 1: working on row 785
# Thread 2: working on row 870
# Thread 3: working on row 835
# Thread 3: working on row 840
# Thread 2: working on row 875
# Thread 1: working on row 790
# Thread 1: working on row 795
# Thread 2: working on row 880
# Thread 1: working on row 800
# Thread 3: working on row 845
# Thread 1: working on row 805
# Thread 0: working on row 685
# Thread 2: working on row 885
# Thread 3: working on row 850
# Thread 2: working on row 890
# Thread 3: working on row 855
# Thread 3: working on row 860
# Thread 1: working on row 810
# Thread 2: working on row 895
# Thread 1: working on row 815
# Thread 3: working on row 865
# Thread 1: working on row 820
# Thread 2: working on row 900
# Thread 2: working on row 905
# Thread 0: working on row 690
# Thread 2: working on row 910
# Thread 0: working on row 695
# Thread 1: working on row 825
# Thread 3: working on row 870Thread 0: working on row 700
#
# Thread 3: working on row 875
# Thread 1: working on row 830
# Thread 2: working on row 915
# Thread 0: working on row 705
# Thread 1: working on row 835
# Thread 3: working on row 880
# Thread 3: working on row 885
# Thread 3: working on row 890
# Thread 2: working on row 920
# Thread 3: working on row 895
# Thread 2: working on row 925
# Thread 0: working on row 710
# Thread 2: working on row 930
# Thread 1: working on row 840
# Thread 2: working on row 935
# Thread 0: working on row 715
# Thread 2: working on row 940
# Thread 2: working on row 945
# Thread 0: working on row 720
# Thread 2: working on row 950
# Thread 0: working on row 725Thread 1: working on row 845
#
# Thread 3: working on row 900
# Thread 3: working on row 905Thread 0: working on row 730
#
# Thread 3: working on row 910
# Thread 2: working on row 955
# Thread 2: working on row 960
# Thread 0: working on row 735
# Thread 3: working on row 915
# Thread 2: working on row 965
# Thread 0: working on row 740
# Thread 2: working on row 970
# Thread 1: working on row 850
# Thread 3: working on row 920
# Thread 1: working on row 855
# Thread 0: working on row 745
# Thread 1: working on row 860
# Thread 3: working on row 925
# Thread 0: working on row 750
# Thread 1: working on row 865
# Thread 2: working on row 975
# Thread 3: working on row 930
# Thread 2: working on row 980
# Thread 2: working on row 985
# Thread 1: working on row 870
# Thread 0: working on row 755
# Thread 2: working on row 990
# Thread 1: working on row 875
# Thread 1: working on row 880
# Thread 0: working on row 760
# Thread 3: working on row 935
# Thread 1: working on row 885
# Thread 3: working on row 940
# Thread 0: working on row 765
# Thread 2: working on row 995
# Thread 3: working on row 945
# Thread 2: working on row 1000
# Thread 0: working on row 770
# Thread 1: working on row 890
# Thread 3: working on row 950
# Thread 0: working on row 775
# Thread 2: working on row 1005
# Thread 1: working on row 895
# Thread 2: working on row 1010
# Thread 3: working on row 955
# Thread 0: working on row 780
# Thread 1: working on row 900
# Thread 3: working on row 960
# Thread 3: working on row 965
# Thread 1: working on row 905
# Thread 0: working on row 785
# Thread 3: working on row 970
# Thread 0: working on row 790
# Thread 3: working on row 975
# Thread 2: working on row 1015
# Thread 0: working on row 795
# Thread 1: working on row 910
# Thread 3: working on row 980
# Thread 1: working on row 915
# Thread 3: working on row 985Thread 0: working on row 800
#
# Thread 3: working on row 990
# Thread 3: working on row 995
# Thread 2: working on row 1020Thread 1: working on row 920
#
# Thread 0: working on row 805
# Thread 0: working on row 810
# Thread 0: working on row 815
# Thread 1: working on row 925
# Thread 0: working on row 820
# Thread 3: working on row 1000
# Thread 2: working on row 1025
# Thread 3: working on row 1005
# Thread 2: working on row 1030
# Thread 1: working on row 930
# Thread 3: working on row 1010
# Thread 1: working on row 935
# Thread 0: working on row 825
# Thread 3: working on row 1015Thread 1: working on row 940
#
# Thread 1: working on row 945
# Thread 2: working on row 1035
# Thread 0: working on row 830
# Thread 2: working on row 1040
# Thread 2: working on row 1045
# Thread 1: working on row 950
# Thread 0: working on row 835
# Thread 1: working on row 955
# Thread 3: working on row 1020
# Thread 3: working on row 1025
# Thread 1: working on row 960
# Thread 2: working on row 1050
# Thread 1: working on row 965
# Thread 3: working on row 1030
# Thread 3: working on row 1035
# Thread 0: working on row 840
# Thread 2: working on row 1055
# Thread 2: working on row 1060
# Thread 2: working on row 1065
# Thread 1: working on row 970
# Thread 2: working on row 1070
# Thread 3: working on row 1040
# Thread 2: working on row 1075
# Thread 1: working on row 975
# Thread 0: working on row 845
# Thread 2: working on row 1080
# Thread 2: working on row 1085
# Thread 1: working on row 980
# Thread 3: working on row 1045
# Thread 0: working on row 850
# Thread 0: working on row 855
# Thread 3: working on row 1050
# Thread 0: working on row 860
# Thread 2: working on row 1090
# Thread 3: working on row 1055
# Thread 0: working on row 865
# Thread 1: working on row 985
# Thread 2: working on row 1095
# Thread 0: working on row 870
# Thread 0: working on row 875
# Thread 2: working on row 1100
# Thread 0: working on row 880
# Thread 2: working on row 1105
# Thread 2: working on row 1110
# Thread 2: working on row 1115
# Thread 1: working on row 990
# Thread 0: working on row 885
# Thread 2: working on row 1120
# Thread 1: working on row 995
# Thread 2: working on row 1125
# Thread 3: working on row 1060
# Thread 1: working on row 1000
# Thread 1: working on row 1005
# Thread 0: working on row 890
# Thread 0: working on row 895
# Thread 1: working on row 1010Thread 2: working on row 1130
#
# Thread 1: working on row 1015
# Thread 3: working on row 1065
# Thread 0: working on row 900
# Thread 2: working on row 1135
# Thread 3: working on row 1070
# Thread 2: working on row 1140
# Thread 2: working on row 1145
# Thread 1: working on row 1020
# Thread 2: working on row 1150
# Thread 3: working on row 1075
# Thread 1: working on row 1025
# Thread 1: working on row 1030
# Thread 0: working on row 905
# Thread 0: working on row 910
# Thread 1: working on row 1035
# Thread 0: working on row 915
# Thread 0: working on row 920
# Thread 3: working on row 1080
# Thread 2: working on row 1155
# Thread 3: working on row 1085
# Thread 3: working on row 1090
# Thread 1: working on row 1040
# Thread 2: working on row 1160
# Thread 3: working on row 1095Thread 2: working on row 1165
#
# Thread 0: working on row 925
# Thread 1: working on row 1045
# Thread 3: working on row 1100
# Thread 0: working on row 930
# Thread 2: working on row 1170
# Thread 1: working on row 1050
# Thread 3: working on row 1105
# Thread 0: working on row 935
# Thread 3: working on row 1110
# Thread 3: working on row 1115
# Thread 1: working on row 1055
# Thread 0: working on row 940
# Thread 1: working on row 1060
# Thread 0: working on row 945
# Thread 3: working on row 1120
# Thread 0: working on row 950
# Thread 2: working on row 1175
# Thread 3: working on row 1125
# Thread 3: working on row 1130
# Thread 0: working on row 955
# Thread 0: working on row 960
# Thread 1: working on row 1065
# Thread 3: working on row 1135
# Thread 2: working on row 1180
# Thread 0: working on row 965
# Thread 1: working on row 1070
# Thread 3: working on row 1140
# Thread 1: working on row 1075
# Thread 2: working on row 1185
# Thread 3: working on row 1145
# Thread 3: working on row 1150Thread 1: working on row 1080
#
# Thread 2: working on row 1190
# Thread 3: working on row 1155
# Thread 1: working on row 1085
# Thread 2: working on row 1195
# Thread 3: working on row 1160
# Thread 2: working on row 1200
# Thread 1: working on row 1090
# Thread 2: working on row 1205
# Thread 3: working on row 1165
# Thread 2: working on row 1210
# Thread 1: working on row 1095
# Thread 3: working on row 1170
# Thread 3: working on row 1175
# Thread 0: working on row 970
# Thread 2: working on row 1215
# Thread 3: working on row 1180
# Thread 2: working on row 1220
# Thread 0: working on row 975
# Thread 2: working on row 1225
# Thread 2: working on row 1230
# Thread 3: working on row 1185
# Thread 3: working on row 1190
# Thread 2: working on row 1235
# Thread 1: working on row 1100
# Thread 2: working on row 1240
# Thread 1: working on row 1105
# Thread 0: working on row 980
# Thread 3: working on row 1195
# Thread 2: working on row 1245
# Thread 0: working on row 985
# Thread 2: working on row 1250
# Thread 3: working on row 1200
# Thread 1: working on row 1110
# Thread 2: working on row 1255
# Thread 3: working on row 1205
# Thread 3: working on row 1210Thread 2: working on row 1260
#
# Thread 0: working on row 990
# Thread 3: working on row 1215
# Thread 2: working on row 1265
# Thread 2: working on row 1270
# Thread 0: working on row 995
# Thread 1: working on row 1115
# Thread 0: working on row 1000
# Thread 2: working on row 1275
# Thread 1: working on row 1120
# Thread 2: working on row 1280
# Thread 0: working on row 1005
# Thread 2: working on row 1285
# Thread 0: working on row 1010
# Thread 1: working on row 1125
# Thread 0: working on row 1015
# Thread 2: working on row 1290
# Thread 3: working on row 1220
# Thread 1: working on row 1130
# Thread 1: working on row 1135
# Thread 1: working on row 1140
# Thread 0: working on row 1020
# Thread 3: working on row 1225
# Thread 0: working on row 1025
# Thread 2: working on row 1295
# Thread 1: working on row 1145
# Thread 3: working on row 1230
# Thread 2: working on row 1300
# Thread 1: working on row 1150
# Thread 0: working on row 1030
# Thread 3: working on row 1235
# Thread 2: working on row 1305
# Thread 0: working on row 1035
# Thread 1: working on row 1155
# Thread 0: working on row 1040
# Thread 2: working on row 1310
# Thread 1: working on row 1160
# Thread 0: working on row 1045
# Thread 0: working on row 1050
# Thread 0: working on row 1055
# Thread 1: working on row 1165
# Thread 3: working on row 1240
# Thread 3: working on row 1245
# Thread 1: working on row 1170
# Thread 1: working on row 1175Thread 0: working on row 1060
#
# Thread 2: working on row 1315
# Thread 1: working on row 1180
# Thread 3: working on row 1250
# Thread 2: working on row 1320
# Thread 0: working on row 1065
# Thread 1: working on row 1185
# Thread 0: working on row 1070
# Thread 2: working on row 1325
# Thread 0: working on row 1075
# Thread 2: working on row 1330
# Thread 1: working on row 1190
# Thread 0: working on row 1080
# Thread 3: working on row 1255
# Thread 1: working on row 1195
# Thread 2: working on row 1335
# Thread 2: working on row 1340
# Thread 2: working on row 1345
# Thread 1: working on row 1200
# Thread 0: working on row 1085
# Thread 3: working on row 1260
# Thread 2: working on row 1350
# Thread 0: working on row 1090
# Thread 1: working on row 1205
# Thread 0: working on row 1095
# Thread 3: working on row 1265
# Thread 1: working on row 1210
# Thread 1: working on row 1215
# Thread 3: working on row 1270
# Thread 2: working on row 1355
# Thread 3: working on row 1275
# Thread 2: working on row 1360
# Thread 1: working on row 1220
# Thread 2: working on row 1365
# Thread 1: working on row 1225Thread 0: working on row 1100
#
# Thread 3: working on row 1280
# Thread 2: working on row 1370
# Thread 1: working on row 1230
# Thread 1: working on row 1235
# Thread 3: working on row 1285
# Thread 3: working on row 1290
# Thread 1: working on row 1240
# Thread 0: working on row 1105Thread 1: working on row 1245
#
# Thread 3: working on row 1295
# Thread 2: working on row 1375
# Thread 0: working on row 1110
# Thread 1: working on row 1250
# Thread 2: working on row 1380
# Thread 1: working on row 1255Thread 3: working on row 1300
#
# Thread 0: working on row 1115
# Thread 3: working on row 1305
# Thread 3: working on row 1310
# Thread 1: working on row 1260
# Thread 3: working on row 1315
# Thread 1: working on row 1265
# Thread 2: working on row 1385
# Thread 2: working on row 1390Thread 3: working on row 1320
#
# Thread 3: working on row 1325
# Thread 2: working on row 1395
# Thread 3: working on row 1330
# Thread 2: working on row 1400
# Thread 0: working on row 1120
# Thread 1: working on row 1270
# Thread 3: working on row 1335
# Thread 1: working on row 1275
# Thread 2: working on row 1405
# Thread 0: working on row 1125
# Thread 0: working on row 1130
# Thread 2: working on row 1410
# Thread 1: working on row 1280
# Thread 0: working on row 1135
# Thread 0: working on row 1140
# Thread 3: working on row 1340
# Thread 3: working on row 1345
# Thread 3: working on row 1350
# Thread 1: working on row 1285
# Thread 3: working on row 1355
# Thread 0: working on row 1145
# Thread 2: working on row 1415
# Thread 0: working on row 1150
# Thread 2: working on row 1420
# Thread 0: working on row 1155
# Thread 0: working on row 1160
# Thread 2: working on row 1425
# Thread 3: working on row 1360
# Thread 2: working on row 1430
# Thread 1: working on row 1290
# Thread 2: working on row 1435
# Thread 1: working on row 1295
# Thread 3: working on row 1365
# Thread 0: working on row 1165
# Thread 1: working on row 1300Thread 2: working on row 1440
#
# Thread 1: working on row 1305
# Thread 0: working on row 1170
# Thread 2: working on row 1445
# Thread 0: working on row 1175
# Thread 0: working on row 1180
# Thread 3: working on row 1370
# Thread 2: working on row 1450
# Thread 3: working on row 1375
# Thread 0: working on row 1185
# Thread 0: working on row 1190
# Thread 0: working on row 1195
# Thread 1: working on row 1310
# Thread 0: working on row 1200
# Thread 2: working on row 1455
# Thread 3: working on row 1380
# Thread 2: working on row 1460
# Thread 3: working on row 1385
# Thread 0: working on row 1205
# Thread 2: working on row 1465
# Thread 2: working on row 1470
# Thread 1: working on row 1315
# Thread 3: working on row 1390
# Thread 0: working on row 1210
# Thread 3: working on row 1395
# Thread 0: working on row 1215
# Thread 0: working on row 1220
# Thread 3: working on row 1400
# Thread 2: working on row 1475
# Thread 2: working on row 1480
# Thread 3: working on row 1405Thread 0: working on row 1225
#
# Thread 0: working on row 1230
# Thread 2: working on row 1485
# Thread 1: working on row 1320
# Thread 0: working on row 1235
# Thread 2: working on row 1490
# Thread 1: working on row 1325
# Thread 0: working on row 1240
# Thread 3: working on row 1410
# Thread 0: working on row 1245
# Thread 2: working on row 1495
# Thread 3: working on row 1415
# Thread 2: working on row 1500
# Thread 0: working on row 1250
# Thread 1: working on row 1330
# Thread 2: working on row 1505
# Thread 0: working on row 1255
# Thread 1: working on row 1335
# Thread 2: working on row 1510
# Thread 3: working on row 1420
# Thread 1: working on row 1340Thread 0: working on row 1260
#
# Thread 3: working on row 1425
# Thread 2: working on row 1515
# Thread 2: working on row 1520
# Thread 2: working on row 1525
# Thread 2: working on row 1530
# Thread 3: working on row 1430
# Thread 1: working on row 1345
# Thread 1: working on row 1350
# Thread 0: working on row 1265
# Thread 0: working on row 1270
# Thread 3: working on row 1435
# Thread 0: working on row 1275
# Thread 2: working on row 1535
# Thread 2: working on row 1540
# Thread 1: working on row 1355
# Thread 0: working on row 1280
# Thread 1: working on row 1360
# Thread 2: working on row 1545
# Thread 1: working on row 1365
# Thread 2: working on row 1550
# Thread 3: working on row 1440
# Thread 3: working on row 1445
# Thread 0: working on row 1285
# Thread 3: working on row 1450
# Thread 3: working on row 1455
# Thread 0: working on row 1290
# Thread 3: working on row 1460
# Thread 1: working on row 1370
# Thread 3: working on row 1465
# Thread 2: working on row 1555
# Thread 3: working on row 1470
# Thread 1: working on row 1375
# Thread 1: working on row 1380
# Thread 2: working on row 1560
# Thread 1: working on row 1385
# Thread 3: working on row 1475Thread 2: working on row 1565
#
# Thread 0: working on row 1295
# Thread 0: working on row 1300
# Thread 2: working on row 1570
# Thread 3: working on row 1480
# Thread 3: working on row 1485
# Thread 1: working on row 1390
# Thread 2: working on row 1575
# Thread 3: working on row 1490
# Thread 3: working on row 1495
# Thread 0: working on row 1305
# Thread 1: working on row 1395
# Thread 1: working on row 1400
# Thread 2: working on row 1580
# Thread 3: working on row 1500
# Thread 1: working on row 1405
# Thread 1: working on row 1410
# Thread 2: working on row 1585
# Thread 1: working on row 1415
# Thread 2: working on row 1590
# Thread 0: working on row 1310Thread 1: working on row 1420
#
# Thread 1: working on row 1425
# Thread 3: working on row 1505
# Thread 2: working on row 1595
# Thread 0: working on row 1315
# Thread 3: working on row 1510
# Thread 3: working on row 1515
# Thread 2: working on row 1600
# Thread 1: working on row 1430
# Thread 2: working on row 1605
# Thread 0: working on row 1320
# Thread 2: working on row 1610
# Thread 3: working on row 1520
# Thread 1: working on row 1435
# Thread 1: working on row 1440
# Thread 3: working on row 1525
# Thread 2: working on row 1615
# Thread 2: working on row 1620
# Thread 0: working on row 1325
# Thread 2: working on row 1625
# Thread 1: working on row 1445
# Thread 3: working on row 1530
# Thread 2: working on row 1630
# Thread 1: working on row 1450
# Thread 3: working on row 1535
# Thread 1: working on row 1455
# Thread 3: working on row 1540
# Thread 2: working on row 1635
# Thread 0: working on row 1330
# Thread 2: working on row 1640
# Thread 3: working on row 1545
# Thread 0: working on row 1335
# Thread 0: working on row 1340
# Thread 2: working on row 1645
# Thread 2: working on row 1650
# Thread 1: working on row 1460
# Thread 1: working on row 1465
# Thread 3: working on row 1550
# Thread 2: working on row 1655
# Thread 2: working on row 1660
# Thread 1: working on row 1470
# Thread 2: working on row 1665
# Thread 0: working on row 1345
# Thread 3: working on row 1555
# Thread 2: working on row 1670
# Thread 1: working on row 1475
# Thread 0: working on row 1350
# Thread 0: working on row 1355
# Thread 1: working on row 1480
# Thread 0: working on row 1360
# Thread 1: working on row 1485
# Thread 2: working on row 1675
# Thread 3: working on row 1560
# Thread 3: working on row 1565
# Thread 2: working on row 1680
# Thread 1: working on row 1490
# Thread 1: working on row 1495
# Thread 1: working on row 1500
# Thread 1: working on row 1505
# Thread 0: working on row 1365
# Thread 2: working on row 1685
# Thread 3: working on row 1570
# Thread 3: working on row 1575
# Thread 0: working on row 1370
# Thread 0: working on row 1375
# Thread 0: working on row 1380
# Thread 3: working on row 1580
# Thread 1: working on row 1510
# Thread 2: working on row 1690
# Thread 0: working on row 1385
# Thread 0: working on row 1390
# Thread 0: working on row 1395
# Thread 1: working on row 1515
# Thread 3: working on row 1585
# Thread 1: working on row 1520
# Thread 0: working on row 1400
# Thread 3: working on row 1590
# Thread 1: working on row 1525
# Thread 2: working on row 1695
# Thread 3: working on row 1595
# Thread 2: working on row 1700
# Thread 2: working on row 1705
# Thread 1: working on row 1530
# Thread 2: working on row 1710
# Thread 2: working on row 1715
# Thread 1: working on row 1535
# Thread 3: working on row 1600
# Thread 1: working on row 1540
# Thread 3: working on row 1605
# Thread 0: working on row 1405
# Thread 1: working on row 1545
# Thread 3: working on row 1610
# Thread 3: working on row 1615
# Thread 3: working on row 1620
# Thread 1: working on row 1550
# Thread 1: working on row 1555
# Thread 3: working on row 1625
# Thread 1: working on row 1560
# Thread 0: working on row 1410
# Thread 3: working on row 1630
# Thread 3: working on row 1635
# Thread 3: working on row 1640
# Thread 3: working on row 1645
# Thread 3: working on row 1650
# Thread 0: working on row 1415
# Thread 1: working on row 1565
# Thread 0: working on row 1420
# Thread 1: working on row 1570
# Thread 1: working on row 1575
# Thread 3: working on row 1655
# Thread 0: working on row 1425
# Thread 3: working on row 1660
# Thread 2: working on row 1720
# Thread 1: working on row 1580
# Thread 3: working on row 1665
# Thread 0: working on row 1430
# Thread 3: working on row 1670
# Thread 3: working on row 1675
# Thread 2: working on row 1725
# Thread 0: working on row 1435
# Thread 2: working on row 1730
# Thread 2: working on row 1735
# Thread 1: working on row 1585
# Thread 3: working on row 1680
# Thread 2: working on row 1740
# Thread 0: working on row 1440
# Thread 2: working on row 1745
# Thread 2: working on row 1750
# Thread 3: working on row 1685
# Thread 3: working on row 1690
# Thread 1: working on row 1590
# Thread 3: working on row 1695
# Thread 1: working on row 1595
# Thread 0: working on row 1445
# Thread 0: working on row 1450
# Thread 1: working on row 1600Thread 0: working on row 1455
#
# Thread 2: working on row 1755
# Thread 3: working on row 1700
# Thread 0: working on row 1460
# Thread 2: working on row 1760
# Thread 2: working on row 1765
# Thread 2: working on row 1770
# Thread 3: working on row 1705
# Thread 1: working on row 1605
# Thread 0: working on row 1465
# Thread 0: working on row 1470
# Thread 0: working on row 1475
# Thread 0: working on row 1480
# Thread 3: working on row 1710
# Thread 3: working on row 1715
# Thread 0: working on row 1485
# Thread 0: working on row 1490
# Thread 2: working on row 1775
# Thread 3: working on row 1720
# Thread 0: working on row 1495
# Thread 2: working on row 1780
# Thread 3: working on row 1725
# Thread 3: working on row 1730
# Thread 3: working on row 1735
# Thread 1: working on row 1610
# Thread 3: working on row 1740
# Thread 3: working on row 1745
# Thread 2: working on row 1785
# Thread 1: working on row 1615Thread 3: working on row 1750
#
# Thread 1: working on row 1620
# Thread 2: working on row 1790Thread 1: working on row 1625
#
# Thread 3: working on row 1755
# Thread 0: working on row 1500
# Thread 1: working on row 1630
# Thread 2: working on row 1795
# Thread 1: working on row 1635
# Thread 3: working on row 1760
# Thread 2: working on row 1800
# Thread 0: working on row 1505
# Thread 2: working on row 1805
# Thread 0: working on row 1510
# Thread 1: working on row 1640
# Thread 0: working on row 1515
# Thread 3: working on row 1765
# Thread 2: working on row 1810
# Thread 3: working on row 1770
# Thread 3: working on row 1775
# Thread 2: working on row 1815
# Thread 2: working on row 1820
# Thread 2: working on row 1825
# Thread 0: working on row 1520
# Thread 3: working on row 1780
# Thread 0: working on row 1525
# Thread 2: working on row 1830
# Thread 2: working on row 1835
# Thread 3: working on row 1785
# Thread 2: working on row 1840
# Thread 3: working on row 1790
# Thread 0: working on row 1530
# Thread 2: working on row 1845
# Thread 2: working on row 1850
# Thread 3: working on row 1795
# Thread 0: working on row 1535
# Thread 2: working on row 1855
# Thread 2: working on row 1860
# Thread 3: working on row 1800
# Thread 0: working on row 1540
# Thread 3: working on row 1805
# Thread 2: working on row 1865
# Thread 0: working on row 1545
# Thread 2: working on row 1870
# Thread 3: working on row 1810
# Thread 0: working on row 1550
# Thread 3: working on row 1815
# Thread 2: working on row 1875
# Thread 3: working on row 1820
# Thread 0: working on row 1555
# Thread 2: working on row 1880
# Thread 2: working on row 1885
# Thread 1: working on row 1645
# Thread 2: working on row 1890
# Thread 0: working on row 1560
# Thread 1: working on row 1650
# Thread 1: working on row 1655
# Thread 3: working on row 1825
# Thread 1: working on row 1660
# Thread 0: working on row 1565
# Thread 1: working on row 1665
# Thread 3: working on row 1830
# Thread 0: working on row 1570
# Thread 3: working on row 1835
# Thread 0: working on row 1575
# Thread 3: working on row 1840
# Thread 3: working on row 1845
# Thread 2: working on row 1895
# Thread 2: working on row 1900
# Thread 0: working on row 1580
# Thread 2: working on row 1905
# Thread 3: working on row 1850
# Thread 0: working on row 1585
# Thread 3: working on row 1855
# Thread 2: working on row 1910
# Thread 0: working on row 1590
# Thread 1: working on row 1670
# Thread 3: working on row 1860
# Thread 3: working on row 1865
# Thread 0: working on row 1595
# Thread 1: working on row 1675
# Thread 0: working on row 1600
# Thread 2: working on row 1915
# Thread 1: working on row 1680
# Thread 1: working on row 1685Thread 3: working on row 1870
#
# Thread 3: working on row 1875
# Thread 2: working on row 1920
# Thread 2: working on row 1925
# Thread 3: working on row 1880
# Thread 2: working on row 1930
# Thread 3: working on row 1885
# Thread 0: working on row 1605
# Thread 0: working on row 1610
# Thread 3: working on row 1890
# Thread 3: working on row 1895
# Thread 1: working on row 1690
# Thread 2: working on row 1935
# Thread 3: working on row 1900
# Thread 0: working on row 1615
# Thread 3: working on row 1905Thread 2: working on row 1940
#
# Thread 1: working on row 1695
# Thread 3: working on row 1910
# Thread 3: working on row 1915
# Thread 1: working on row 1700
# Thread 0: working on row 1620
# Thread 2: working on row 1945
# Thread 2: working on row 1950
# Thread 1: working on row 1705
# Thread 2: working on row 1955
# Thread 2: working on row 1960
# Thread 0: working on row 1625
# Thread 3: working on row 1920
# Thread 0: working on row 1630
# Thread 3: working on row 1925
# Thread 2: working on row 1965
# Thread 2: working on row 1970
# Thread 1: working on row 1710
# Thread 3: working on row 1930
# Thread 0: working on row 1635
# Thread 0: working on row 1640
# Thread 1: working on row 1715
# Thread 3: working on row 1935
# Thread 2: working on row 1975
# Thread 2: working on row 1980
# Thread 2: working on row 1985
# Thread 0: working on row 1645
# Thread 1: working on row 1720
# Thread 1: working on row 1725
# Thread 2: working on row 1990
# Thread 0: working on row 1650
# Thread 2: working on row 1995
# Thread 1: working on row 1730
# Thread 1: working on row 1735
# Thread 0: working on row 1655
# Thread 3: working on row 1940
# Thread 2: working on row 2000
# Thread 2: working on row 2005
# Thread 2: working on row 2010
# Thread 3: working on row 1945
# Thread 1: working on row 1740
# Thread 0: working on row 1660
# Thread 3: working on row 1950
# Thread 3: working on row 1955
# Thread 1: working on row 1745
# Thread 0: working on row 1665
# Thread 2: working on row 2015
# Thread 2: working on row 2020
# Thread 3: working on row 1960
# Thread 0: working on row 1670
# Thread 3: working on row 1965
# Thread 3: working on row 1970
# Thread 0: working on row 1675
# Thread 2: working on row 2025
# Thread 2: working on row 2030
# Thread 1: working on row 1750
# Thread 3: working on row 1975
# Thread 1: working on row 1755
# Thread 1: working on row 1760Thread 0: working on row 1680
#
# Thread 3: working on row 1980
# Thread 2: working on row 2035
# Thread 2: working on row 2040
# Thread 2: working on row 2045
# Thread 2: working on row 2050
# Thread 3: working on row 1985
# Thread 0: working on row 1685
# Thread 2: working on row 2055
# Thread 0: working on row 1690
# Thread 3: working on row 1990
# Thread 3: working on row 1995
# Thread 1: working on row 1765
# Thread 0: working on row 1695
# Thread 2: working on row 2060
# Thread 0: working on row 1700
# Thread 1: working on row 1770
# Thread 2: working on row 2065
# Thread 0: working on row 1705
# Thread 2: working on row 2070
# Thread 1: working on row 1775
# Thread 3: working on row 2000
# Thread 3: working on row 2005
# Thread 0: working on row 1710
# Thread 1: working on row 1780
# Thread 2: working on row 2075
# Thread 3: working on row 2010
# Thread 0: working on row 1715
# Thread 2: working on row 2080
# Thread 2: working on row 2085
# Thread 0: working on row 1720
# Thread 3: working on row 2015
# Thread 0: working on row 1725
# Thread 2: working on row 2090
# Thread 1: working on row 1785
# Thread 3: working on row 2020
# Thread 0: working on row 1730Thread 1: working on row 1790
#
# Thread 2: working on row 2095
# Thread 0: working on row 1735
# Thread 3: working on row 2025
# Thread 1: working on row 1795
# Thread 2: working on row 2100
# Thread 3: working on row 2030
# Thread 0: working on row 1740
# Thread 2: working on row 2105
# Thread 3: working on row 2035
# Thread 2: working on row 2110
# Thread 1: working on row 1800
# Thread 0: working on row 1745
# Thread 3: working on row 2040
# Thread 3: working on row 2045
# Thread 3: working on row 2050
# Thread 0: working on row 1750
# Thread 1: working on row 1805
# Thread 3: working on row 2055
# Thread 0: working on row 1755
# Thread 2: working on row 2115
# Thread 0: working on row 1760
# Thread 1: working on row 1810
# Thread 3: working on row 2060
# Thread 3: working on row 2065
# Thread 2: working on row 2120
# Thread 2: working on row 2125
# Thread 3: working on row 2070
# Thread 3: working on row 2075
# Thread 0: working on row 1765
# Thread 2: working on row 2130
# Thread 1: working on row 1815
# Thread 3: working on row 2080
# Thread 0: working on row 1770
# Thread 3: working on row 2085
# Thread 0: working on row 1775
# Thread 0: working on row 1780
# Thread 3: working on row 2090
# Thread 3: working on row 2095
# Thread 2: working on row 2135
# Thread 0: working on row 1785
# Thread 0: working on row 1790
# Thread 1: working on row 1820
# Thread 3: working on row 2100
# Thread 3: working on row 2105
# Thread 2: working on row 2140
# Thread 3: working on row 2110
# Thread 0: working on row 1795
# Thread 0: working on row 1800
# Thread 3: working on row 2115
# Thread 1: working on row 1825
# Thread 2: working on row 2145
# Thread 3: working on row 2120
# Thread 2: working on row 2150
# Thread 2: working on row 2155
# Thread 3: working on row 2125
# Thread 2: working on row 2160
# Thread 3: working on row 2130
# Thread 2: working on row 2165
# Thread 0: working on row 1805
# Thread 2: working on row 2170
# Thread 0: working on row 1810
# Thread 3: working on row 2135
# Thread 1: working on row 1830
# Thread 1: working on row 1835
# Thread 0: working on row 1815
# Thread 3: working on row 2140
# Thread 1: working on row 1840
# Thread 1: working on row 1845
# Thread 3: working on row 2145
# Thread 0: working on row 1820
# Thread 3: working on row 2150
# Thread 1: working on row 1850
# Thread 3: working on row 2155
# Thread 1: working on row 1855
# Thread 0: working on row 1825
# Thread 0: working on row 1830
# Thread 1: working on row 1860
# Thread 0: working on row 1835
# Thread 3: working on row 2160
# Thread 3: working on row 2165
# Thread 1: working on row 1865
# Thread 3: working on row 2170
# Thread 0: working on row 1840
# Thread 1: working on row 1870
# Thread 1: working on row 1875
# Thread 1: working on row 1880
# Thread 3: working on row 2175
# Thread 1: working on row 1885
# Thread 0: working on row 1845
# Thread 1: working on row 1890
# Thread 1: working on row 1895
# Thread 1: working on row 1900
# Thread 0: working on row 1850
# Thread 3: working on row 2180
# Thread 1: working on row 1905
# Thread 3: working on row 2185
# Thread 0: working on row 1855
# Thread 3: working on row 2190
# Thread 0: working on row 1860
# ...
#
# Thread 0: working on row 32640
# Thread 1: working on row 33045
# Thread 0: working on row 32645
# Thread 0: working on row 32650
# Thread 0: working on row 32655
# Thread 0: working on row 32660
# Thread 0: working on row 32665
# Thread 1: working on row 33050
# Thread 1: working on row 33055
# Thread 0: working on row 32670
# Thread 1: working on row 33060
# Thread 0: working on row 32675
# Thread 1: working on row 33065
# Thread 0: working on row 32680
# Thread 0: working on row 32685
# Thread 1: working on row 33070
# Thread 0: working on row 32690
# Thread 0: working on row 32695
# Thread 1: working on row 33075
# Thread 0: working on row 32700
# Thread 1: working on row 33080
# Thread 0: working on row 32705
# Thread 1: working on row 33085
# Thread 0: working on row 32710
# Thread 0: working on row 32715
# Thread 0: working on row 32720
# Thread 1: working on row 33090
# Thread 0: working on row 32725
# Thread 1: working on row 33095
# Thread 1: working on row 33100
# Thread 0: working on row 32730
# Thread 1: working on row 33105
# Thread 0: working on row 32735
# Thread 1: working on row 33110
# Thread 0: working on row 32740
# Thread 1: working on row 33115
# Thread 1: working on row 33120
# Thread 0: working on row 32745
# Thread 1: working on row 33125
# Thread 0: working on row 32750
# Thread 0: working on row 32755Thread 1: working on row 33130
#
# Thread 1: working on row 33135
# Thread 0: working on row 32760
# Thread 0: working on row 32765
# Thread 0: working on row 32770
# Thread 0: working on row 32775
# Thread 1: working on row 33140
# Thread 0: working on row 32780
# Thread 1: working on row 33145
# Thread 0: working on row 32785
# Thread 1: working on row 33150
# Thread 0: working on row 32790
# Thread 1: working on row 33155
# Thread 1: working on row 33160
# Thread 1: working on row 33165
# Thread 0: working on row 32795
# Thread 0: working on row 32800
# Thread 1: working on row 33170
# Thread 1: working on row 33175
# Thread 1: working on row 33180
# Thread 0: working on row 32805
# Thread 1: working on row 33185
# Thread 1: working on row 33190
# Thread 0: working on row 32810
# Thread 0: working on row 32815
# Thread 0: working on row 32820
# Thread 0: working on row 32825
# Thread 1: working on row 33195
# Thread 1: working on row 33200
# Thread 1: working on row 33205
# Thread 1: working on row 33210
# Thread 0: working on row 32830
# Thread 1: working on row 33215
# Thread 0: working on row 32835
# Thread 1: working on row 33220
# Thread 1: working on row 33225
# Thread 0: working on row 32840
# Thread 1: working on row 33230
# Thread 1: working on row 33235
# Thread 1: working on row 33240
# Thread 1: working on row 33245
# Thread 1: working on row 33250
# Thread 1: working on row 33255
# Thread 1: working on row 33260
# Thread 1: working on row 33265
# Thread 0: working on row 32845
# Thread 1: working on row 33270
# Thread 1: working on row 33275
# Thread 1: working on row 33280
# Thread 0: working on row 32850
# Thread 1: working on row 33285
# Thread 0: working on row 32855
# Thread 0: working on row 32860
# Thread 1: working on row 33290
# Thread 1: working on row 33295
# Thread 0: working on row 32865
# Thread 0: working on row 32870
# Thread 1: working on row 33300
# Thread 0: working on row 32875Thread 1: working on row 33305
#
# Thread 0: working on row 32880
# Thread 0: working on row 32885
# Thread 1: working on row 33310
# Thread 1: working on row 33315
# Thread 0: working on row 32890
# Thread 1: working on row 33320
# Thread 0: working on row 32895
# Thread 1: working on row 33325
# Thread 0: working on row 32900
# Thread 1: working on row 33330
# Thread 1: working on row 33335
# Thread 1: working on row 33340
# Thread 1: working on row 33345
# Thread 0: working on row 32905
# Thread 1: working on row 33350
# Thread 0: working on row 32910
# Thread 1: working on row 33355
# Thread 0: working on row 32915
# Thread 0: working on row 32920
# Thread 1: working on row 33360
# Thread 0: working on row 32925
# Thread 0: working on row 32930
# Thread 0: working on row 32935
# Thread 1: working on row 33365
# Thread 0: working on row 32940
# Thread 1: working on row 33370
# Thread 1: working on row 33375
# Thread 0: working on row 32945
# Thread 1: working on row 33380
# Thread 0: working on row 32950
# Thread 1: working on row 33385
# Thread 0: working on row 32955
# Thread 0: working on row 32960
# Thread 1: working on row 33390
# Thread 0: working on row 32965
# Thread 0: working on row 32970
# Thread 1: working on row 33395
# Thread 0: working on row 32975
# Thread 1: working on row 33400
# Thread 0: working on row 32980
# Thread 1: working on row 33405
# Thread 0: working on row 32985
# Thread 1: working on row 33410
# Thread 1: working on row 33415
# Thread 0: working on row 32990
# Thread 1: working on row 33420
# Thread 0: working on row 32995
# Thread 1: working on row 33425
# Thread 1: working on row 33430
# Thread 0: working on row 33000
# Thread 1: working on row 33435
# Thread 1: working on row 33440
# Thread 1: working on row 33445
# Thread 0: working on row 33005
# Thread 1: working on row 33450
# Thread 0: working on row 33010
# Thread 0: working on row 33015
# Thread 1: working on row 33455
# Thread 1: working on row 33460
# Thread 0: working on row 33020
# Thread 1: working on row 33465
# Thread 0: working on row 33025
# Thread 0: working on row 33030
# Thread 0: working on row 33035
# Thread 0: working on row 33040
# Thread 0: working on row 33045
# Thread 0: working on row 33050
# Thread 0: working on row 33055
# Thread 0: working on row 33060
# Thread 0: working on row 33065
# Thread 0: working on row 33070
# Thread 0: working on row 33075
# Thread 0: working on row 33080
# Thread 0: working on row 33085
# Thread 0: working on row 33090
# Thread 0: working on row 33095
# Thread 0: working on row 33100
# Thread 0: working on row 33105
# Thread 0: working on row 33110
# Thread 0: working on row 33115
# Thread 0: working on row 33120
# Thread 0: working on row 33125
# Thread 0: working on row 33130
# Thread 0: working on row 33135
# Thread 0: working on row 33140
# Thread 0: working on row 33145
# Thread 0: working on row 33150
# Thread 0: working on row 33155
# Thread 0: working on row 33160
# Thread 0: working on row 33165
# Thread 0: working on row 33170
# Thread 0: working on row 33175
# Thread 0: working on row 33180
# Thread 0: working on row 33185
# Thread 0: working on row 33190
# Thread 0: working on row 33195
# Thread 0: working on row 33200
# Thread 0: working on row 33205
# Thread 0: working on row 33210
# Thread 0: working on row 33215
# Thread 0: working on row 33220
# Thread 0: working on row 33225
# Thread 0: working on row 33230
# Thread 1: working on row 33470
# Thread 0: working on row 33235
# Thread 0: working on row 33240Thread 1: working on row 33475
#
# Thread 1: working on row 33480
# Thread 1: working on row 33485
# Thread 0: working on row 33245
# Thread 1: working on row 33490
# Thread 1: working on row 33495
# Thread 0: working on row 33250
# Thread 1: working on row 33500
# Thread 0: working on row 33255
# Thread 0: working on row 33260
# Thread 1: working on row 33505
# Thread 1: working on row 33510
# Thread 1: working on row 33515
# Thread 0: working on row 33265
# Thread 0: working on row 33270
# Thread 1: working on row 33520
# Thread 0: working on row 33275
# Thread 1: working on row 33525
# Thread 0: working on row 33280
# Thread 1: working on row 33530
# Thread 1: working on row 33535
# Thread 0: working on row 33285
# Thread 0: working on row 33290
# Thread 0: working on row 33295
# Thread 0: working on row 33300
# Thread 1: working on row 33540
# Thread 1: working on row 33545
# Thread 0: working on row 33305
# Thread 0: working on row 33310
# Thread 0: working on row 33315
# Thread 0: working on row 33320
# Thread 0: working on row 33325
# Thread 1: working on row 33550
# Thread 0: working on row 33330
# Thread 0: working on row 33335
# Thread 1: working on row 33555
# Thread 0: working on row 33340
# Thread 1: working on row 33560
# Thread 1: working on row 33565
# Thread 0: working on row 33345
# Thread 0: working on row 33350
# Thread 1: working on row 33570
# Thread 0: working on row 33355
# Thread 1: working on row 33575
# Thread 0: working on row 33360
# Thread 1: working on row 33580
# Thread 1: working on row 33585
# Thread 0: working on row 33365
# Thread 0: working on row 33370
# Thread 0: working on row 33375
# Thread 1: working on row 33590
# Thread 0: working on row 33380
# Thread 1: working on row 33595
# Thread 0: working on row 33385
# Thread 1: working on row 33600
# Thread 1: working on row 33605
# Thread 0: working on row 33390
# Thread 1: working on row 33610
# Thread 0: working on row 33395
# Thread 0: working on row 33400
# Thread 1: working on row 33615
# Thread 0: working on row 33405
# Thread 1: working on row 33620
# Thread 0: working on row 33410
# Thread 0: working on row 33415
# Thread 1: working on row 33625
# Thread 0: working on row 33420
# Thread 1: working on row 33630
# Thread 1: working on row 33635
# Thread 1: working on row 33640
# Thread 0: working on row 33425
# Thread 0: working on row 33430
# Thread 0: working on row 33435
# Thread 0: working on row 33440
# Thread 1: working on row 33645
# Thread 1: working on row 33650
# Thread 1: working on row 33655
# Thread 1: working on row 33660
# Thread 1: working on row 33665
# Thread 0: working on row 33445
# Thread 0: working on row 33450
# Thread 1: working on row 33670
# Thread 0: working on row 33455
# Thread 1: working on row 33675
# Thread 1: working on row 33680
# Thread 1: working on row 33685
# Thread 0: working on row 33460
# Thread 0: working on row 33465
# Thread 1: working on row 33690
# Thread 1: working on row 33695
# Thread 0: working on row 33470
# Thread 1: working on row 33700
# Thread 0: working on row 33475
# Thread 1: working on row 33705
# Thread 0: working on row 33480Thread 1: working on row 33710
#
# Thread 1: working on row 33715
# Thread 1: working on row 33720
# Thread 1: working on row 33725
# Thread 0: working on row 33485
# Thread 0: working on row 33490
# Thread 1: working on row 33730
# Thread 1: working on row 33735
# Thread 1: working on row 33740Thread 0: working on row 33495
#
# Thread 1: working on row 33745
# Thread 0: working on row 33500
# Thread 0: working on row 33505
# Thread 1: working on row 33750
# Thread 1: working on row 33755
# Thread 0: working on row 33510
# Thread 0: working on row 33515
# Thread 1: working on row 33760
# Thread 1: working on row 33765
# Thread 0: working on row 33520
# Thread 1: working on row 33770
# Thread 0: working on row 33525
# Thread 1: working on row 33775
# Thread 1: working on row 33780
# Thread 0: working on row 33530
# Thread 0: working on row 33535
# Thread 1: working on row 33785
# Thread 1: working on row 33790
# Thread 0: working on row 33540
# Thread 1: working on row 33795
# Thread 1: working on row 33800
# Thread 1: working on row 33805
# Thread 1: working on row 33810
# Thread 0: working on row 33545
# Thread 1: working on row 33815
# Thread 1: working on row 33820
# Thread 0: working on row 33550
# Thread 0: working on row 33555
# Thread 1: working on row 33825
# Thread 0: working on row 33560
# Thread 0: working on row 33565
# Thread 1: working on row 33830
# Thread 1: working on row 33835
# Thread 0: working on row 33570
# Thread 0: working on row 33575
# Thread 1: working on row 33840
# Thread 1: working on row 33845
# Thread 0: working on row 33580
# Thread 1: working on row 33850
# Thread 1: working on row 33855
# Thread 1: working on row 33860
# Thread 0: working on row 33585
# Thread 1: working on row 33865
# Thread 1: working on row 33870
# Thread 0: working on row 33590
# Thread 1: working on row 33875
# Thread 1: working on row 33880
# Thread 1: working on row 33885
# Thread 0: working on row 33595
# Thread 0: working on row 33600
# Thread 1: working on row 33890
# Thread 0: working on row 33605
# Thread 1: working on row 33895
# Thread 0: working on row 33610
# Thread 1: working on row 33900
# Thread 0: working on row 33615
# Thread 0: working on row 33620
# Thread 1: working on row 33905
# Thread 0: working on row 33625
# Thread 0: working on row 33630
# Thread 1: working on row 33910
# Thread 1: working on row 33915
# Thread 1: working on row 33920
# Thread 0: working on row 33635
# Thread 1: working on row 33925
# Thread 0: working on row 33640
# Thread 1: working on row 33930
# Thread 1: working on row 33935
# Thread 0: working on row 33645
# Thread 1: working on row 33940
# Thread 1: working on row 33945
# Thread 0: working on row 33650
# Thread 0: working on row 33655
# Thread 0: working on row 33660
# Thread 1: working on row 33950
# Thread 0: working on row 33665
# Thread 1: working on row 33955
# Thread 1: working on row 33960
# Thread 0: working on row 33670
# Thread 0: working on row 33675
# Thread 0: working on row 33680
# Thread 1: working on row 33965
# Thread 0: working on row 33685Thread 1: working on row 33970
#
# Thread 1: working on row 33975
# Thread 0: working on row 33690
# Thread 0: working on row 33695
# Thread 1: working on row 33980
# Thread 1: working on row 33985
# Thread 0: working on row 33700
# Thread 1: working on row 33990
# Thread 0: working on row 33705
# Thread 1: working on row 33995
# Thread 1: working on row 34000
# Thread 0: working on row 33710
# Thread 0: working on row 33715
# Thread 1: working on row 34005
# Thread 0: working on row 33720
# Thread 1: working on row 34010
# Thread 1: working on row 34015
# Thread 0: working on row 33725
# Thread 0: working on row 33730
# Thread 0: working on row 33735
# Thread 0: working on row 33740
# Thread 1: working on row 34020
# Thread 0: working on row 33745
# Thread 0: working on row 33750
# Thread 1: working on row 34025
# Thread 0: working on row 33755
# Thread 1: working on row 34030
# Thread 1: working on row 34035
# Thread 1: working on row 34040
# Thread 1: working on row 34045
# Thread 0: working on row 33760
# Thread 1: working on row 34050
# Thread 1: working on row 34055
# Thread 0: working on row 33765Thread 1: working on row 34060
#
# Thread 0: working on row 33770
# Thread 1: working on row 34065
# Thread 0: working on row 33775
# Thread 1: working on row 34070
# Thread 0: working on row 33780
# Thread 1: working on row 34075
# Thread 1: working on row 34080
# Thread 0: working on row 33785
# Thread 0: working on row 33790
# Thread 1: working on row 34085
# Thread 0: working on row 33795
# Thread 0: working on row 33800
# Thread 0: working on row 33805
# Thread 1: working on row 34090
# Thread 0: working on row 33810
# Thread 1: working on row 34095
# Thread 0: working on row 33815
# Thread 1: working on row 34100
# Thread 1: working on row 34105Thread 0: working on row 33820
#
# Thread 1: working on row 34110
# Thread 0: working on row 33825
# Thread 0: working on row 33830
# Thread 1: working on row 34115
# Thread 0: working on row 33835
# Thread 1: working on row 34120
# Thread 1: working on row 34125
# Thread 0: working on row 33840
# Thread 0: working on row 33845
# Thread 0: working on row 33850
# Thread 0: working on row 33855
# Thread 0: working on row 33860
# Thread 0: working on row 33865
# Thread 0: working on row 33870
# Thread 0: working on row 33875
# Thread 0: working on row 33880
# Thread 0: working on row 33885
# Thread 0: working on row 33890
# Thread 0: working on row 33895
# Thread 0: working on row 33900
# Thread 0: working on row 33905
# Thread 0: working on row 33910
# Thread 0: working on row 33915
# Thread 0: working on row 33920
# Thread 0: working on row 33925
# Thread 0: working on row 33930
# Thread 0: working on row 33935
# Thread 0: working on row 33940
# Thread 0: working on row 33945
# Thread 0: working on row 33950
# Thread 0: working on row 33955
# Thread 0: working on row 33960
# Thread 0: working on row 33965
# Thread 0: working on row 33970
# Thread 0: working on row 33975
# Thread 0: working on row 33980
# Thread 0: working on row 33985
# Thread 0: working on row 33990
# Thread 0: working on row 33995
# Thread 0: working on row 34000
# Thread 0: working on row 34005
# Thread 0: working on row 34010
# Thread 0: working on row 34015
# Thread 0: working on row 34020
# Thread 0: working on row 34025
# Thread 0: working on row 34030
# Thread 0: working on row 34035
# Thread 0: working on row 34040
# Thread 0: working on row 34045
# Thread 0: working on row 34050
# Thread 0: working on row 34055
# Thread 0: working on row 34060
# Thread 0: working on row 34065
# Thread 0: working on row 34070
# Thread 0: working on row 34075
# Thread 0: working on row 34080
# Thread 0: working on row 34085
# Thread 0: working on row 34090
# Thread 0: working on row 34095
# Thread 0: working on row 34100
# Thread 0: working on row 34105
# Thread 0: working on row 34110
# Thread 0: working on row 34115
# Thread 0: working on row 34120
# Thread 0: working on row 34125

# %%
def process_vader_sentiment(dataframe: pd.DataFrame=None)->pd.DataFrame:
    output_dict = {'neg':[],'neu':[],'pos':[]}
    for idx, row in enumerate(dataframe.to_dict('records')):
        if idx % 50 == 0:
            print(f'print {idx}')
        text = [line.strip() for line in row['transcript']]
        single_sentence = ' '.join(text)
        sentiment_scores = vader_analyzer.polarity_scores(single_sentence)
        output_dict['neg'].append(sentiment_scores['neg'])
        output_dict['neu'].append(sentiment_scores['neu'])
        output_dict['pos'].append(sentiment_scores['pos'])
    pd.DataFrame(output_dict).to_pickle('../data/Eleven/vader_sentiment.pkl')

# %%
# Load the Loughran-McDonald sentiment word lists
positive_words = set(open('LoughranMcDonald_Positive.csv', 'r').read().splitlines())
negative_words = set(open('LoughranMcDonald_Negative.csv', 'r').read().splitlines())

# Sample text for sentiment analysis
text = "The company reported record-breaking profits and strong revenue growth."

# Tokenize the text (you may need to install a tokenization library like NLTK)
from nltk.tokenize import word_tokenize
tokens = word_tokenize(text.lower())  # Convert to lowercase for case-insensitive matching

# Initialize sentiment scores
positive_score = 0
negative_score = 0

# Calculate sentiment scores based on the Loughran-McDonald dictionary
for token in tokens:
    if token in positive_words:
        positive_score += 1
    elif token in negative_words:
        negative_score += 1
